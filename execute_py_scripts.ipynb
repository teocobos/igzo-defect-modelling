# %%
# !python scripts/structure_generation/validate_igzo_orderings.py
# Out:
# Found 4 ordered IGZO models.
#
# ...
# IGZO ORDERED STRUCTURE VALIDATION
# ...
# Model                              Atoms   Ordered   Min dist / Å         Space group
# ----------------------------------------------------------------------------------------------------
# igzo_crystal_ordered_001              21      True          1.930          P3m1 (156)
# igzo_crystal_ordered_002              21      True          1.930          P3m1 (156)
# igzo_crystal_ordered_003              21      True          1.930           R3m (160)
# igzo_crystal_ordered_004              21      True          1.930          P3m1 (156)
# ...
#
# igzo_crystal_ordered_001
#   Formula: Zn3 In3 Ga3 O12
#   Errors: none
#   Warnings: none
#
# igzo_crystal_ordered_002
#   Formula: Zn3 In3 Ga3 O12
#   Errors: none
#   Warnings: none
#
# igzo_crystal_ordered_003
#   Formula: Zn3 In3 Ga3 O12
#   Errors: none
#   Warnings: none
#
# igzo_crystal_ordered_004
#   Formula: Zn3 In3 Ga3 O12
#   Errors: none
#   Warnings: none
#
# ...
